# %% [markdown]
# #### -----------------------------------------------------------------------------<br>Copyright (c) 2024, Lucid Vision Labs, Inc.
# ##### THE  SOFTWARE  IS  PROVIDED  "AS IS",  WITHOUT  WARRANTY  OF  ANY  KIND,<br>EXPRESS  OR  IMPLIED,  INCLUDING  BUT  NOT  LIMITED  TO  THE  WARRANTIES<br>OF  MERCHANTABILITY,  FITNESS  FOR  A  PARTICULAR  PURPOSE  AND<br>NONINFRINGEMENT.  IN  NO  EVENT  SHALL  THE  AUTHORS  OR  COPYRIGHT  HOLDERS<br>BE  LIABLE  FOR  ANY  CLAIM,  DAMAGES  OR  OTHER  LIABILITY,  WHETHER  IN  AN<br>ACTION  OF  CONTRACT,  TORT  OR  OTHERWISE,  ARISING  FROM,  OUT  OF  OR  IN<br>CONNECTION  WITH  THE  SOFTWARE  OR  THE  USE  OR  OTHER  DEALINGS  IN  THE  SOFTWARE.<br>-----------------------------------------------------------------------------

# %%
import time
from arena_api.system import system

# %% [markdown]
# #### Acquisition: Introduction
# >    This example introduces the basics of image acquisition. This includes
#     setting image acquisition and buffer handling modes, setting the device to
#     automatically negotiate packet size, and setting the stream packet resend
#     node before starting the image stream. The example then starts acquiring
#     images by grabbing and requeuing buffers, and retrieving data on images
#     before finally stopping the image stream.

# %%
"""
This function waits for the user to connect a device before raising an exception
"""

tries = 0
tries_max = 6
sleep_time_secs = 10
while tries < tries_max:  # Wait for device for 60 seconds
    devices = system.create_device()
    if not devices:
        print(
            f'Try {tries+1} of {tries_max}: waiting for {sleep_time_secs} '
            f'secs for a device to be connected!')
        for sec_count in range(sleep_time_secs):
            time.sleep(1)
            print(f'{sec_count + 1 } seconds passed ',
                  '.' * sec_count, end='\r')
            tries += 1
    else:
        print(f'Created {len(devices)} device(s)')
        break
else:
    raise Exception(f'No device found! Please connect a device and run '
                    f'the example again.')

device = system.select_device(devices)
nodemap = device.nodemap
tl_stream_nodemap = device.tl_stream_nodemap
print(f'Device used in the example:\n\t{device}')
# Out:
# Created 1 device(s)
#   Only one device detected:  ('1c:0f:af:4c:c3:c7', 'HTW003S-001', '', '169.254.200.195')
#     Automatically selecting this device.
# Device used in the example:
# 	('1c:0f:af:4c:c3:c7', 'HTW003S-001', '', '169.254.200.195')

# %% [markdown]
# ##### Store initial values
# > These initial values are restored to the device after the example is completed

# %%
print(f"Store initial values")
initial_acquisition_mode = nodemap.get_node("AcquisitionMode").value
width_initial = nodemap.get_node("Width").value
height_initial = nodemap.get_node("Height").value
# Out:
# Store initial values

# %% [markdown]
# ##### Configure device settings

# %%
nodemap.get_node("AcquisitionMode").value = "Continuous"

# %% [markdown]
# ##### Set buffer handling mode
# >  Set buffer handling mode before starting the stream. Starting the
#     stream requires the buffer handling mode to be set beforehand. The
#     buffer handling mode determines the order and behavior of buffers in
#     the underlying stream engine. Setting the buffer handling mode to
#     'NewestOnly' ensures the most recent image is delivered, even if it
#     means skipping frames.

# %%
tl_stream_nodemap["StreamBufferHandlingMode"].value = "NewestOnly"

# %% [markdown]
# ##### Enable stream auto negotiate packet size
# > Setting the stream packet size is done before starting the stream.
#     Setting the stream to automatically negotiate packet size instructs the
#     camera to receive the largest packet size that the system will allow.
#     This generally increases frame rate and results in fewer interrupts per
#     image, thereby reducing CPU load on the host system. Ethernet settings
#     may also be manually changed to allow for a larger packet size.

# %%
tl_stream_nodemap['StreamAutoNegotiatePacketSize'].value = True

# %% [markdown]
# ##### Enable stream packet resend
# > Enable stream packet resend before starting the stream. Images are sent
#     from the camera to the host in packets using UDP protocol, which
#     includes a header image number, packet number, and timestamp
#     information. If a packet is missed while receiving an image, a packet
#     resend is requested and this information is used to retrieve and
#     redeliver the missing packet in the correct order.

# %%
tl_stream_nodemap['StreamPacketResendEnable'].value = True

# %% [markdown]
# ##### Set features before streaming.-------------------------------------------
# >  Set width and height to their max values

# %%
# print("Getting 'Width' and 'Height' Nodes")
# width_node = device.nodemap.get_node('Width')
# height_node = device.nodemap.get_node('Height')

# if width_node is None or height_node is None:
#     raise Exception('Width or Height node not found in the nodemap.')

# print("Setting 'Width' and 'Height' Nodes value to their max values")
# width_node.value = width_node.max
# height_node.value = height_node.max

# %% [markdown]
# ##### Grab images -------------------------------------------------------------
# > - Starting the stream allocates buffers, which can be passed in as
#  an argument (default: 10), and begins filling them with data.
#  Buffers must later be requeued to avoid memory leaks.<br>
# > - 'Device.get_buffer()' with no arguments returns one buffer(NOT IN A LIST)<br>
# > - 'Device.get_buffer(30)' returns 30 buffers(IN A LIST)<br>
# > - 'Device.requeue_buffer()' takes a buffer or many buffers in a list or tuple

# %%
import os
os.chdir('D:\LiDAR Capture')
from arena_api.__future__.save import Writer  # Import the Writer class
from arena_api.system import system

number_of_buffers = 1000

# Assume device initialization and selection here
devices = system.create_device()
device = system.select_device(devices)

device.start_stream(number_of_buffers)
print(f'Stream started with {number_of_buffers} buffers')

print(f'Get {number_of_buffers} buffers in a list')
buffers = []
for _ in range(number_of_buffers):
    buffer = device.get_buffer()
    buffers.append(buffer)
print("Success")

# Create a Writer instance
writer = Writer()

# Create a directory to save PLY files if it doesn't exist
output_folder = '3D_data_output'
os.makedirs(output_folder, exist_ok=True)

'''
Print image buffer info
    Buffers contain image data.
    Image data can also be copied and converted using BufferFactory.
    That is necessary to retain image data, as we must also requeue the buffer.
'''
for count, buffer in enumerate(buffers):
    print(f'\tbuffer{count:{2}} received | '
          f'Width = {buffer.width} pxl, '
          f'Height = {buffer.height} pxl, '
          f'Pixel Format = {buffer.pixel_format.name}')
    
    filename = os.path.join(output_folder, f'data_{count}.ply')
    writer.save(buffer, filename)
    device.requeue_buffer(buffer)
    print(f'\tbuffer{count:{2}} requeued')

print(f'Requeued {number_of_buffers} buffers')

device.stop_stream()
print('Stream stopped')
# Out:
#   Only one device detected:  ('1c:0f:af:4c:c3:c7', 'HTW003S-001', '', '169.254.200.195')
#     Automatically selecting this device.
# Stream started with 1000 buffers
# Get 1000 buffers in a list
# Success
# 	buffer 0 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 0 requeued
# 	buffer 1 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 1 requeued
# 	buffer 2 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 2 requeued
# 	buffer 3 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 3 requeued
# 	buffer 4 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 4 requeued
# 	buffer 5 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 5 requeued
# 	buffer 6 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 6 requeued
# 	buffer 7 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 7 requeued
# 	buffer 8 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 8 requeued
# 	buffer 9 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer 9 requeued
# 	buffer10 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer10 requeued
# 	buffer11 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer11 requeued
# 	buffer12 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer12 requeued
# 	buffer13 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer13 requeued
# 	buffer14 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer14 requeued
# 	buffer15 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer15 requeued
# 	buffer16 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer16 requeued
# 	buffer17 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer17 requeued
# 	buffer18 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer18 requeued
# 	buffer19 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer19 requeued
# 	buffer20 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer20 requeued
# 	buffer21 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer21 requeued
# 	buffer22 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer22 requeued
# 	buffer23 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer23 requeued
# 	buffer24 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer24 requeued
# 	buffer25 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer25 requeued
# 	buffer26 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer26 requeued
# 	buffer27 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer27 requeued
# 	buffer28 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer28 requeued
# 	buffer29 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer29 requeued
# 	buffer30 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer30 requeued
# 	buffer31 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer31 requeued
# 	buffer32 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer32 requeued
# 	buffer33 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer33 requeued
# 	buffer34 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer34 requeued
# 	buffer35 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer35 requeued
# 	buffer36 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer36 requeued
# 	buffer37 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer37 requeued
# 	buffer38 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer38 requeued
# 	buffer39 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer39 requeued
# 	buffer40 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer40 requeued
# 	buffer41 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer41 requeued
# 	buffer42 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer42 requeued
# 	buffer43 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer43 requeued
# 	buffer44 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer44 requeued
# 	buffer45 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer45 requeued
# 	buffer46 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer46 requeued
# 	buffer47 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer47 requeued
# 	buffer48 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer48 requeued
# 	buffer49 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer49 requeued
# 	buffer50 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer50 requeued
# 	buffer51 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer51 requeued
# 	buffer52 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer52 requeued
# 	buffer53 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer53 requeued
# 	buffer54 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer54 requeued
# 	buffer55 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer55 requeued
# 	buffer56 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer56 requeued
# 	buffer57 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer57 requeued
# 	buffer58 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer58 requeued
# 	buffer59 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer59 requeued
# 	buffer60 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer60 requeued
# 	buffer61 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer61 requeued
# 	buffer62 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer62 requeued
# 	buffer63 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer63 requeued
# 	buffer64 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer64 requeued
# 	buffer65 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer65 requeued
# 	buffer66 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer66 requeued
# 	buffer67 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer67 requeued
# 	buffer68 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer68 requeued
# 	buffer69 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer69 requeued
# 	buffer70 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer70 requeued
# 	buffer71 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer71 requeued
# 	buffer72 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer72 requeued
# 	buffer73 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer73 requeued
# 	buffer74 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer74 requeued
# 	buffer75 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer75 requeued
# 	buffer76 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer76 requeued
# 	buffer77 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer77 requeued
# 	buffer78 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer78 requeued
# 	buffer79 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer79 requeued
# 	buffer80 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer80 requeued
# 	buffer81 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer81 requeued
# 	buffer82 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer82 requeued
# 	buffer83 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer83 requeued
# 	buffer84 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer84 requeued
# 	buffer85 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer85 requeued
# 	buffer86 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer86 requeued
# 	buffer87 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer87 requeued
# 	buffer88 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer88 requeued
# 	buffer89 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer89 requeued
# 	buffer90 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer90 requeued
# 	buffer91 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer91 requeued
# 	buffer92 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer92 requeued
# 	buffer93 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer93 requeued
# 	buffer94 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer94 requeued
# 	buffer95 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer95 requeued
# 	buffer96 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer96 requeued
# 	buffer97 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer97 requeued
# 	buffer98 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer98 requeued
# 	buffer99 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer99 requeued
# 	buffer100 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer100 requeued
# 	buffer101 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer101 requeued
# 	buffer102 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer102 requeued
# 	buffer103 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer103 requeued
# 	buffer104 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer104 requeued
# 	buffer105 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer105 requeued
# 	buffer106 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer106 requeued
# 	buffer107 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer107 requeued
# 	buffer108 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer108 requeued
# 	buffer109 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer109 requeued
# 	buffer110 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer110 requeued
# 	buffer111 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer111 requeued
# 	buffer112 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer112 requeued
# 	buffer113 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer113 requeued
# 	buffer114 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer114 requeued
# 	buffer115 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer115 requeued
# 	buffer116 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer116 requeued
# 	buffer117 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer117 requeued
# 	buffer118 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer118 requeued
# 	buffer119 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer119 requeued
# 	buffer120 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer120 requeued
# 	buffer121 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer121 requeued
# 	buffer122 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer122 requeued
# 	buffer123 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer123 requeued
# 	buffer124 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer124 requeued
# 	buffer125 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer125 requeued
# 	buffer126 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer126 requeued
# 	buffer127 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer127 requeued
# 	buffer128 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer128 requeued
# 	buffer129 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer129 requeued
# 	buffer130 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer130 requeued
# 	buffer131 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer131 requeued
# 	buffer132 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer132 requeued
# 	buffer133 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer133 requeued
# 	buffer134 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer134 requeued
# 	buffer135 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer135 requeued
# 	buffer136 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer136 requeued
# 	buffer137 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer137 requeued
# 	buffer138 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer138 requeued
# 	buffer139 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer139 requeued
# 	buffer140 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer140 requeued
# 	buffer141 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer141 requeued
# 	buffer142 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer142 requeued
# 	buffer143 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer143 requeued
# 	buffer144 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer144 requeued
# 	buffer145 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer145 requeued
# 	buffer146 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer146 requeued
# 	buffer147 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer147 requeued
# 	buffer148 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer148 requeued
# 	buffer149 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer149 requeued
# 	buffer150 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer150 requeued
# 	buffer151 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer151 requeued
# 	buffer152 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer152 requeued
# 	buffer153 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer153 requeued
# 	buffer154 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer154 requeued
# 	buffer155 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer155 requeued
# 	buffer156 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer156 requeued
# 	buffer157 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer157 requeued
# 	buffer158 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer158 requeued
# 	buffer159 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer159 requeued
# 	buffer160 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer160 requeued
# 	buffer161 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer161 requeued
# 	buffer162 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer162 requeued
# 	buffer163 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer163 requeued
# 	buffer164 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer164 requeued
# 	buffer165 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer165 requeued
# 	buffer166 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer166 requeued
# 	buffer167 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer167 requeued
# 	buffer168 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer168 requeued
# 	buffer169 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer169 requeued
# 	buffer170 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer170 requeued
# 	buffer171 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer171 requeued
# 	buffer172 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer172 requeued
# 	buffer173 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer173 requeued
# 	buffer174 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer174 requeued
# 	buffer175 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer175 requeued
# 	buffer176 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer176 requeued
# 	buffer177 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer177 requeued
# 	buffer178 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer178 requeued
# 	buffer179 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer179 requeued
# 	buffer180 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer180 requeued
# 	buffer181 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer181 requeued
# 	buffer182 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer182 requeued
# 	buffer183 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer183 requeued
# 	buffer184 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer184 requeued
# 	buffer185 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer185 requeued
# 	buffer186 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer186 requeued
# 	buffer187 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer187 requeued
# 	buffer188 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer188 requeued
# 	buffer189 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer189 requeued
# 	buffer190 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer190 requeued
# 	buffer191 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer191 requeued
# 	buffer192 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer192 requeued
# 	buffer193 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer193 requeued
# 	buffer194 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer194 requeued
# 	buffer195 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer195 requeued
# 	buffer196 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer196 requeued
# 	buffer197 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer197 requeued
# 	buffer198 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer198 requeued
# 	buffer199 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer199 requeued
# 	buffer200 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer200 requeued
# 	buffer201 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer201 requeued
# 	buffer202 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer202 requeued
# 	buffer203 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer203 requeued
# 	buffer204 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer204 requeued
# 	buffer205 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer205 requeued
# 	buffer206 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer206 requeued
# 	buffer207 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer207 requeued
# 	buffer208 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer208 requeued
# 	buffer209 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer209 requeued
# 	buffer210 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer210 requeued
# 	buffer211 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer211 requeued
# 	buffer212 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer212 requeued
# 	buffer213 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer213 requeued
# 	buffer214 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer214 requeued
# 	buffer215 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer215 requeued
# 	buffer216 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer216 requeued
# 	buffer217 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer217 requeued
# 	buffer218 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer218 requeued
# 	buffer219 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer219 requeued
# 	buffer220 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer220 requeued
# 	buffer221 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer221 requeued
# 	buffer222 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer222 requeued
# 	buffer223 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer223 requeued
# 	buffer224 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer224 requeued
# 	buffer225 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer225 requeued
# 	buffer226 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer226 requeued
# 	buffer227 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer227 requeued
# 	buffer228 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer228 requeued
# 	buffer229 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer229 requeued
# 	buffer230 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer230 requeued
# 	buffer231 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer231 requeued
# 	buffer232 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer232 requeued
# 	buffer233 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer233 requeued
# 	buffer234 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer234 requeued
# 	buffer235 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer235 requeued
# 	buffer236 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer236 requeued
# 	buffer237 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer237 requeued
# 	buffer238 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer238 requeued
# 	buffer239 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer239 requeued
# 	buffer240 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer240 requeued
# 	buffer241 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer241 requeued
# 	buffer242 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer242 requeued
# 	buffer243 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer243 requeued
# 	buffer244 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer244 requeued
# 	buffer245 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer245 requeued
# 	buffer246 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer246 requeued
# 	buffer247 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer247 requeued
# 	buffer248 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer248 requeued
# 	buffer249 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer249 requeued
# 	buffer250 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer250 requeued
# 	buffer251 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer251 requeued
# 	buffer252 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer252 requeued
# 	buffer253 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer253 requeued
# 	buffer254 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer254 requeued
# 	buffer255 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer255 requeued
# 	buffer256 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer256 requeued
# 	buffer257 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer257 requeued
# 	buffer258 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer258 requeued
# 	buffer259 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer259 requeued
# 	buffer260 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer260 requeued
# 	buffer261 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer261 requeued
# 	buffer262 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer262 requeued
# 	buffer263 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer263 requeued
# 	buffer264 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer264 requeued
# 	buffer265 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer265 requeued
# 	buffer266 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer266 requeued
# 	buffer267 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer267 requeued
# 	buffer268 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer268 requeued
# 	buffer269 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer269 requeued
# 	buffer270 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer270 requeued
# 	buffer271 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer271 requeued
# 	buffer272 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer272 requeued
# 	buffer273 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer273 requeued
# 	buffer274 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer274 requeued
# 	buffer275 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer275 requeued
# 	buffer276 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer276 requeued
# 	buffer277 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer277 requeued
# 	buffer278 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer278 requeued
# 	buffer279 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer279 requeued
# 	buffer280 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer280 requeued
# 	buffer281 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer281 requeued
# 	buffer282 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer282 requeued
# 	buffer283 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer283 requeued
# 	buffer284 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer284 requeued
# 	buffer285 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer285 requeued
# 	buffer286 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer286 requeued
# 	buffer287 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer287 requeued
# 	buffer288 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer288 requeued
# 	buffer289 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer289 requeued
# 	buffer290 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer290 requeued
# 	buffer291 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer291 requeued
# 	buffer292 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer292 requeued
# 	buffer293 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer293 requeued
# 	buffer294 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer294 requeued
# 	buffer295 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer295 requeued
# 	buffer296 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer296 requeued
# 	buffer297 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer297 requeued
# 	buffer298 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer298 requeued
# 	buffer299 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer299 requeued
# 	buffer300 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer300 requeued
# 	buffer301 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer301 requeued
# 	buffer302 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer302 requeued
# 	buffer303 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer303 requeued
# 	buffer304 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer304 requeued
# 	buffer305 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer305 requeued
# 	buffer306 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer306 requeued
# 	buffer307 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer307 requeued
# 	buffer308 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer308 requeued
# 	buffer309 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer309 requeued
# 	buffer310 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer310 requeued
# 	buffer311 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer311 requeued
# 	buffer312 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer312 requeued
# 	buffer313 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer313 requeued
# 	buffer314 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer314 requeued
# 	buffer315 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer315 requeued
# 	buffer316 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer316 requeued
# 	buffer317 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer317 requeued
# 	buffer318 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer318 requeued
# 	buffer319 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer319 requeued
# 	buffer320 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer320 requeued
# 	buffer321 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer321 requeued
# 	buffer322 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer322 requeued
# 	buffer323 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer323 requeued
# 	buffer324 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer324 requeued
# 	buffer325 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer325 requeued
# 	buffer326 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer326 requeued
# 	buffer327 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer327 requeued
# 	buffer328 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer328 requeued
# 	buffer329 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer329 requeued
# 	buffer330 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer330 requeued
# 	buffer331 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer331 requeued
# 	buffer332 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer332 requeued
# 	buffer333 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer333 requeued
# 	buffer334 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer334 requeued
# 	buffer335 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer335 requeued
# 	buffer336 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer336 requeued
# 	buffer337 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer337 requeued
# 	buffer338 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer338 requeued
# 	buffer339 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer339 requeued
# 	buffer340 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer340 requeued
# 	buffer341 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer341 requeued
# 	buffer342 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer342 requeued
# 	buffer343 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer343 requeued
# 	buffer344 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer344 requeued
# 	buffer345 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer345 requeued
# 	buffer346 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer346 requeued
# 	buffer347 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer347 requeued
# 	buffer348 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer348 requeued
# 	buffer349 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer349 requeued
# 	buffer350 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer350 requeued
# 	buffer351 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer351 requeued
# 	buffer352 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer352 requeued
# 	buffer353 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer353 requeued
# 	buffer354 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer354 requeued
# 	buffer355 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer355 requeued
# 	buffer356 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer356 requeued
# 	buffer357 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer357 requeued
# 	buffer358 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer358 requeued
# 	buffer359 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer359 requeued
# 	buffer360 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer360 requeued
# 	buffer361 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer361 requeued
# 	buffer362 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer362 requeued
# 	buffer363 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer363 requeued
# 	buffer364 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer364 requeued
# 	buffer365 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer365 requeued
# 	buffer366 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer366 requeued
# 	buffer367 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer367 requeued
# 	buffer368 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer368 requeued
# 	buffer369 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer369 requeued
# 	buffer370 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer370 requeued
# 	buffer371 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer371 requeued
# 	buffer372 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer372 requeued
# 	buffer373 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer373 requeued
# 	buffer374 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer374 requeued
# 	buffer375 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer375 requeued
# 	buffer376 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer376 requeued
# 	buffer377 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer377 requeued
# 	buffer378 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer378 requeued
# 	buffer379 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer379 requeued
# 	buffer380 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer380 requeued
# 	buffer381 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer381 requeued
# 	buffer382 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer382 requeued
# 	buffer383 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer383 requeued
# 	buffer384 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer384 requeued
# 	buffer385 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer385 requeued
# 	buffer386 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer386 requeued
# 	buffer387 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer387 requeued
# 	buffer388 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer388 requeued
# 	buffer389 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer389 requeued
# 	buffer390 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer390 requeued
# 	buffer391 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer391 requeued
# 	buffer392 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer392 requeued
# 	buffer393 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer393 requeued
# 	buffer394 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer394 requeued
# 	buffer395 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer395 requeued
# 	buffer396 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer396 requeued
# 	buffer397 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer397 requeued
# 	buffer398 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer398 requeued
# 	buffer399 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer399 requeued
# 	buffer400 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer400 requeued
# 	buffer401 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer401 requeued
# 	buffer402 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer402 requeued
# 	buffer403 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer403 requeued
# 	buffer404 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer404 requeued
# 	buffer405 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer405 requeued
# 	buffer406 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer406 requeued
# 	buffer407 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer407 requeued
# 	buffer408 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer408 requeued
# 	buffer409 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer409 requeued
# 	buffer410 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer410 requeued
# 	buffer411 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer411 requeued
# 	buffer412 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer412 requeued
# 	buffer413 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer413 requeued
# 	buffer414 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer414 requeued
# 	buffer415 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer415 requeued
# 	buffer416 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer416 requeued
# 	buffer417 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer417 requeued
# 	buffer418 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer418 requeued
# 	buffer419 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer419 requeued
# 	buffer420 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer420 requeued
# 	buffer421 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer421 requeued
# 	buffer422 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer422 requeued
# 	buffer423 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer423 requeued
# 	buffer424 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer424 requeued
# 	buffer425 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer425 requeued
# 	buffer426 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer426 requeued
# 	buffer427 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer427 requeued
# 	buffer428 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer428 requeued
# 	buffer429 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer429 requeued
# 	buffer430 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer430 requeued
# 	buffer431 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer431 requeued
# 	buffer432 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer432 requeued
# 	buffer433 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer433 requeued
# 	buffer434 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer434 requeued
# 	buffer435 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer435 requeued
# 	buffer436 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer436 requeued
# 	buffer437 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer437 requeued
# 	buffer438 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer438 requeued
# 	buffer439 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer439 requeued
# 	buffer440 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer440 requeued
# 	buffer441 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer441 requeued
# 	buffer442 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer442 requeued
# 	buffer443 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer443 requeued
# 	buffer444 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer444 requeued
# 	buffer445 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer445 requeued
# 	buffer446 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer446 requeued
# 	buffer447 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer447 requeued
# ...
# 	buffer850 requeued
# 	buffer851 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer851 requeued
# 	buffer852 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer852 requeued
# 	buffer853 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer853 requeued
# 	buffer854 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer854 requeued
# 	buffer855 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer855 requeued
# 	buffer856 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer856 requeued
# 	buffer857 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer857 requeued
# 	buffer858 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer858 requeued
# 	buffer859 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer859 requeued
# 	buffer860 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer860 requeued
# 	buffer861 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer861 requeued
# 	buffer862 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer862 requeued
# 	buffer863 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer863 requeued
# 	buffer864 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer864 requeued
# 	buffer865 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer865 requeued
# 	buffer866 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer866 requeued
# 	buffer867 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer867 requeued
# 	buffer868 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer868 requeued
# 	buffer869 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer869 requeued
# 	buffer870 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer870 requeued
# 	buffer871 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer871 requeued
# 	buffer872 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer872 requeued
# 	buffer873 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer873 requeued
# 	buffer874 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer874 requeued
# 	buffer875 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer875 requeued
# 	buffer876 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer876 requeued
# 	buffer877 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer877 requeued
# 	buffer878 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer878 requeued
# 	buffer879 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer879 requeued
# 	buffer880 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer880 requeued
# 	buffer881 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer881 requeued
# 	buffer882 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer882 requeued
# 	buffer883 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer883 requeued
# 	buffer884 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer884 requeued
# 	buffer885 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer885 requeued
# 	buffer886 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer886 requeued
# 	buffer887 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer887 requeued
# 	buffer888 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer888 requeued
# 	buffer889 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer889 requeued
# 	buffer890 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer890 requeued
# 	buffer891 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer891 requeued
# 	buffer892 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer892 requeued
# 	buffer893 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer893 requeued
# 	buffer894 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer894 requeued
# 	buffer895 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer895 requeued
# 	buffer896 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer896 requeued
# 	buffer897 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer897 requeued
# 	buffer898 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer898 requeued
# 	buffer899 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer899 requeued
# 	buffer900 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer900 requeued
# 	buffer901 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer901 requeued
# 	buffer902 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer902 requeued
# 	buffer903 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer903 requeued
# 	buffer904 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer904 requeued
# 	buffer905 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer905 requeued
# 	buffer906 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer906 requeued
# 	buffer907 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer907 requeued
# 	buffer908 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer908 requeued
# 	buffer909 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer909 requeued
# 	buffer910 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer910 requeued
# 	buffer911 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer911 requeued
# 	buffer912 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer912 requeued
# 	buffer913 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer913 requeued
# 	buffer914 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer914 requeued
# 	buffer915 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer915 requeued
# 	buffer916 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer916 requeued
# 	buffer917 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer917 requeued
# 	buffer918 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer918 requeued
# 	buffer919 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer919 requeued
# 	buffer920 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer920 requeued
# 	buffer921 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer921 requeued
# 	buffer922 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer922 requeued
# 	buffer923 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer923 requeued
# 	buffer924 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer924 requeued
# 	buffer925 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer925 requeued
# 	buffer926 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer926 requeued
# 	buffer927 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer927 requeued
# 	buffer928 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer928 requeued
# 	buffer929 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer929 requeued
# 	buffer930 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer930 requeued
# 	buffer931 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer931 requeued
# 	buffer932 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer932 requeued
# 	buffer933 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer933 requeued
# 	buffer934 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer934 requeued
# 	buffer935 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer935 requeued
# 	buffer936 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer936 requeued
# 	buffer937 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer937 requeued
# 	buffer938 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer938 requeued
# 	buffer939 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer939 requeued
# 	buffer940 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer940 requeued
# 	buffer941 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer941 requeued
# 	buffer942 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer942 requeued
# 	buffer943 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer943 requeued
# 	buffer944 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer944 requeued
# 	buffer945 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer945 requeued
# 	buffer946 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer946 requeued
# 	buffer947 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer947 requeued
# 	buffer948 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer948 requeued
# 	buffer949 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer949 requeued
# 	buffer950 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer950 requeued
# 	buffer951 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer951 requeued
# 	buffer952 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer952 requeued
# 	buffer953 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer953 requeued
# 	buffer954 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer954 requeued
# 	buffer955 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer955 requeued
# 	buffer956 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer956 requeued
# 	buffer957 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer957 requeued
# 	buffer958 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer958 requeued
# 	buffer959 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer959 requeued
# 	buffer960 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer960 requeued
# 	buffer961 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer961 requeued
# 	buffer962 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer962 requeued
# 	buffer963 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer963 requeued
# 	buffer964 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer964 requeued
# 	buffer965 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer965 requeued
# 	buffer966 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer966 requeued
# 	buffer967 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer967 requeued
# 	buffer968 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer968 requeued
# 	buffer969 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer969 requeued
# 	buffer970 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer970 requeued
# 	buffer971 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer971 requeued
# 	buffer972 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer972 requeued
# 	buffer973 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer973 requeued
# 	buffer974 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer974 requeued
# 	buffer975 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer975 requeued
# 	buffer976 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer976 requeued
# 	buffer977 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer977 requeued
# 	buffer978 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer978 requeued
# 	buffer979 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer979 requeued
# 	buffer980 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer980 requeued
# 	buffer981 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer981 requeued
# 	buffer982 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer982 requeued
# 	buffer983 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer983 requeued
# 	buffer984 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer984 requeued
# 	buffer985 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer985 requeued
# 	buffer986 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer986 requeued
# 	buffer987 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer987 requeued
# 	buffer988 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer988 requeued
# 	buffer989 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer989 requeued
# 	buffer990 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer990 requeued
# 	buffer991 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer991 requeued
# 	buffer992 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer992 requeued
# 	buffer993 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer993 requeued
# 	buffer994 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer994 requeued
# 	buffer995 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer995 requeued
# 	buffer996 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer996 requeued
# 	buffer997 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer997 requeued
# 	buffer998 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer998 requeued
# 	buffer999 received | Width = 640 pxl, Height = 480 pxl, Pixel Format = Coord3D_ABCY16
# 	buffer999 requeued
# Requeued 1000 buffers
# Stream stopped

# %% [markdown]
# ##### Clean up ----------------------------------------------------------------
# > - Restore initial values to the device.
# > - Destroy device. This call is optional and will automatically be
#   called for any remaining devices when the system module is unloading.

# %%
# nodemap.get_node("AcquisitionMode").value = initial_acquisition_mode
# nodemap.get_node("Width").value = width_initial
# nodemap.get_node("Height").value = height_initial

system.destroy_device()
print('Destroyed all created devices')
# Out:
# Destroyed all created devices
